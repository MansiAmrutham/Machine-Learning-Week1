# %%
import pandas as pd

# %%
data = {
    'Name': ['Ramesh', 'Mahesh', 'Suresh'],
    'Age': [25, 30, 35],
    'City': ['Banglore', 'Mumbai', 'Delhi']
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      Name  Age      City
# 0  Ramesh   25  Banglore
# 1  Mahesh   30    Mumbai
# 2  Suresh   35     Delhi

# %%
df.head(2)
# Out:
#      Name  Age      City
# 0  Ramesh   25  Banglore
# 1  Mahesh   30    Mumbai

# %%
df['Age']
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %%
df.loc[(df['Age'] > 26)]
# Out:
#      Name  Age    City
# 1  Mahesh   30  Mumbai
# 2  Suresh   35   Delhi

# %%
df['Country'] = 'India'

# %%
df
# Out:
#      Name  Age      City Country
# 0  Ramesh   25  Banglore   India
# 1  Mahesh   30    Mumbai   India
# 2  Suresh   35     Delhi   India

# %%
data1 = {
    'Name': ['Ramesh', 'Mahesh', 'Suresh'],
    'Age': [25, None, 35],
    'City': ['Banglore', 'Mumbai', 'Delhi']
}

# %%
df2 = pd.DataFrame(data1)

# %%
df2
# Out:
#      Name   Age      City
# 0  Ramesh  25.0  Banglore
# 1  Mahesh   NaN    Mumbai
# 2  Suresh  35.0     Delhi

# %%
df2.iloc[1,1]
# Out:
# nan

# %%
df2.iloc[1,1] = (df2.iloc[0,1]+df2.iloc[2,1])/2

# %%
df2
# Out:
#      Name   Age      City
# 0  Ramesh  25.0  Banglore
# 1  Mahesh  30.0    Mumbai
# 2  Suresh  35.0     Delhi
